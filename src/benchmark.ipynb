# %% [markdown]
# # This Script for test benchmark
# * Yolov8 model m benchmark
# * Yolov8 model l benchmark
# * Yolov8 medel x benchmark

# %% [markdown]
# ### 1. Yolov8-m
# * epoch : 100
# * train dataset : mgen solution AI research team's dataset
# * benchmark data : mgen solution AI research team's dataset

# %%
from ultralytics.yolo.utils.benchmarks import benchmark

benchmark(model='/workspace/yolov8/dev/results/m_model_epoch100_batch32_mgen/weights/best.pt', imgsz=640, half=True, device="0,1,2,3")
# Out:
# Ultralytics YOLOv8.0.120 🚀 Python-3.10.9 torch-2.0.0 CUDA:0 (NVIDIA RTX A5000, 24248MiB)
# Setup complete ✅ (104 CPUs, 251.5 GB RAM, 281.5/878.2 GB disk)
#
# Benchmarks complete for best.pt on coco8.yaml at imgsz=640 (515.11s)
#                    Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)
# 0                 PyTorch       ✅       49.6               0.0023                   48.97
# 1             TorchScript       ✅       99.1               0.0013                    4.68
# 2                    ONNX       ✅       49.4               0.0012                   17.58
# 3                OpenVINO       ❌        0.0                  NaN                     NaN
# 4                TensorRT       ✅       51.5               0.0012                    2.50
# 5                  CoreML       ❌        0.0                  NaN                     NaN
# 6   TensorFlow SavedModel       ❎      247.1                  NaN                     NaN
# ...
